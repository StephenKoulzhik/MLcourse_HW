# %% [markdown]
# ## Simple Linear Model vs Convolutional NN for MNIST digits classification
#
# In this notebook we will compare the performance of two networks for classifying digits from MNIST dataset: first model is the simple fully connected linear model; the second one is convolutional NN.

# %%
import os
import torch
import numpy as np
from torch import nn
from torch.utils.data import DataLoader
from torchvision import datasets, transforms
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import trange
# %matplotlib inline

# %%
from pathlib import Path
import requests
import pickle
import gzip

DATA_PATH = Path("data")
PATH = DATA_PATH / "mnist"

PATH.mkdir(parents=True, exist_ok=True)

URL = "https://github.com/pytorch/tutorials/raw/master/_static/"
FILENAME = "mnist.pkl.gz"

if not (PATH / FILENAME).exists():
        content = requests.get(URL + FILENAME).content
        (PATH / FILENAME).open("wb").write(content)


with gzip.open((PATH / FILENAME).as_posix(), "rb") as f:
        ((X_train, y_train), (X_test, y_test), _) = pickle.load(f, encoding="latin-1")

# %%
index = 54
plt.imshow(x_train[index].reshape((28, 28)))
print(y_train[index])
# Out:
# 9

# %% [markdown]
# ## Linear model

# %%
class Bobby(nn.Module):
    
    
    def __init__(self):
        super(Bobby, self).__init__()
        self.l1 = nn.Linear(784, 512)
        self.l2 = nn.Linear(512, 128)
        self.l3 = nn.Linear(128, 10)
        self.act_func = nn.ReLU()
    
    
    def forward(self, x):
        x = self.l1(x)
        x = self.act_func(x)
        x = self.l2(x)
        x = self.act_func(x)
        x = self.l3(x)
        return x
        
    
device = "cuda" if torch.cuda.is_available() else "cpu"
model = Bobby().to(device)
print(model)
print(device)
# Out:
# Bobby(
#   (l1): Linear(in_features=784, out_features=512, bias=True)
#   (l2): Linear(in_features=512, out_features=128, bias=True)
#   (l3): Linear(in_features=128, out_features=10, bias=True)
#   (act_func): ReLU()
# )
# cpu

# %%
batch_size = 32
loss_func = nn.CrossEntropyLoss()
optim = torch.optim.Adam(model.parameters())
losses, accuracies = [], []
for i in (t := trange(1000)):
    samp = np.random.randint(0, X_train.shape[0], size=batch_size)
    X = torch.tensor(X_train[samp].reshape((-1, 784))).float()
    y = torch.tensor(y_train[samp]).long()
    optim.zero_grad()
    out = model(X)
    preds = torch.argmax(out, dim=1)
    accuracy = (y == preds).float().mean()
    loss = loss_func(out, y)
    loss.backward()
    optim.step()
    loss, accuracy = loss.item(), accuracy.item()
    losses.append(loss)
    accuracies.append(accuracy)
    t.set_description("loss %2.f accuracy %2.f" % (loss, accuracy))

    
plt.ylim(-0.1, 1.5)
plt.plot(losses)
plt.plot(accuracies)
# Out:
# loss  0 accuracy  1: 100%|█████████████████| 1000/1000 [00:07<00:00, 125.33it/s]

# %%
X_valid = torch.tensor(X_test.reshape(-1, 784)).float()
out = model(X_valid)

# %%
preds = torch.argmax(out, dim=1)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test, preds)
# Out:
# 0.9556

# %% [markdown]
# Alright, not bad, Linear Bobby. Let's see how the second model will do

# %% [markdown]
# ## Convolutional model

# %%
import torch.nn.functional as F

# %%
class ConvBobby(nn.Module):
    
    def __init__(self):
        super(ConvBobby, self).__init__()
        
        #first conv layer
        self.conv1 = nn.Conv2d(in_channels=1, out_channels=16, kernel_size=(5, 5), stride=1, padding=2)
        self.relu1 = nn.ReLU()
        self.maxpool1 = nn.MaxPool2d(kernel_size=(2, 2))
        
        #second conv layer
        self.conv2 = nn.Conv2d(in_channels=16, out_channels=32, kernel_size=(5, 5), stride=1, padding=2)
        self.relu2 = nn.ReLU()
        self.maxpool2 = nn.MaxPool2d(kernel_size=(2, 2))
        
        #first fully connected linear layer
        self.linear1 = nn.Linear(in_features=32*7*7, out_features=256)
        self.relu3 = nn.ReLU()
        
        #second fully connected layer
        self.linear2 = nn.Linear(in_features=256, out_features=10)
        self.output = nn.Softmax(dim=1)
#         self.output = nn.ReLU()
        
        
    def forward(self, x):
        x = self.conv1(x)
        x = self.relu1(x)
        x = self.maxpool1(x)
        
        x = self.conv2(x)
        x = self.relu2(x)
        x = self.maxpool2(x)
        
        x = x.view(-1, 32*7*7)
        x = self.linear1(x)
        x = self.relu3(x)
        
        x = self.linear2(x)
        x = self.output(x)
        
        return x
    

device = "cuda" if torch.cuda.is_available() else "cpu"
model_conv = ConvBobby().to(device)
print(model_conv)
print(device)
# Out:
# ConvBobby(
#   (conv1): Conv2d(1, 16, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#   (relu1): ReLU()
#   (maxpool1): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#   (conv2): Conv2d(16, 32, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#   (relu2): ReLU()
#   (maxpool2): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#   (linear1): Linear(in_features=1568, out_features=256, bias=True)
#   (relu3): ReLU()
#   (linear2): Linear(in_features=256, out_features=10, bias=True)
#   (output): Softmax(dim=1)
# )
# cpu

# %%
batch_size = 1
loss_func = nn.CrossEntropyLoss()
optim = torch.optim.Adam(model_conv.parameters())
new_losses, y_true, full_preds = [], [], []

for epoch in range(2):
    running_loss = 0
    for i in (t := trange(10000)):
        #getting a random batch 
        samp = np.random.randint(0, X_train.shape[0], size=1)
        X = torch.tensor(X_train[samp].reshape((-1, 28, 28))).float()
        y = torch.tensor(y_train[samp]).long()

        #zero the gradient
        optim.zero_grad()

        #make predictions 
        out = model_conv(X)
        preds = torch.argmax(out, dim=1)
        
        y_true.append(y)
        full_preds.append(preds)

        #Loss function
        loss = loss_func(out, y)
        loss.backward()

        #Adjust the weights
        optim.step()

#         loss, accuracy = loss.item(), accuracy.item()
        new_losses.append(loss)
        new_accuracies.append(accuracy)
        running_loss += loss.item()
#         t.set_description("loss %2.f accuracy %2.f" % (loss, accuracy))
        
        if (i % 1000) == 999:
            print("Epoch %s" % (epoch + 1))
            print("Batch %s" % (i + 1))
            y_true = torch.tensor(y_true).long()
            full_preds = torch.tensor(full_preds).long()
            acc = accuracy_score(y_true, full_preds)
            print("Loss is: ", running_loss / 1000, sep='')
            print("Accuracy is: ", acc)
            running_loss = 0
            y_true, full_preds = [], []

    
# plt.ylim(-0.1, 1.5)
# plt.plot(new_losses)
# plt.plot(new_accuracies)
# Out:
#  10%|███▊                                 | 1025/10000 [00:04<00:38, 230.80it/s]
# Epoch 1
# Batch 1000
# Loss is: 1.586092917203903
# Accuracy is:  0.881
#  20%|███████▌                             | 2048/10000 [00:07<00:32, 242.56it/s]
# Epoch 1
# Batch 2000
# Loss is: 1.5550523550510407
# Accuracy is:  0.905
#  30%|███████████▏                         | 3017/10000 [00:11<00:25, 275.84it/s]
# Epoch 1
# Batch 3000
# Loss is: 1.578561235666275
# Accuracy is:  0.884
#  40%|██████████████▉                      | 4021/10000 [00:17<00:36, 161.72it/s]
# Epoch 1
# Batch 4000
# Loss is: 1.5755708111524582
# Accuracy is:  0.885
#  50%|██████████████████▋                  | 5048/10000 [00:26<00:21, 234.55it/s]
# Epoch 1
# Batch 5000
# Loss is: 1.5592997407913207
# Accuracy is:  0.902
#  60%|██████████████████████▎              | 6042/10000 [00:29<00:14, 272.70it/s]
# Epoch 1
# Batch 6000
# Loss is: 1.563207946419716
# Accuracy is:  0.899
#  70%|██████████████████████████           | 7038/10000 [00:33<00:11, 250.35it/s]
# Epoch 1
# Batch 7000
# Loss is: 1.5496631385087967
# Accuracy is:  0.91
#  80%|█████████████████████████████▊       | 8045/10000 [00:37<00:07, 246.78it/s]
# Epoch 1
# Batch 8000
# Loss is: 1.5685355738401412
# Accuracy is:  0.892
#  90%|█████████████████████████████████▍   | 9033/10000 [00:42<00:04, 237.38it/s]
# Epoch 1
# Batch 9000
# Loss is: 1.534280194759369
# Accuracy is:  0.929
# 100%|████████████████████████████████████| 10000/10000 [00:46<00:00, 216.45it/s]
# Epoch 1
# Batch 10000
# Loss is: 1.5375383634567261
# Accuracy is:  0.924
#  10%|███▊                                 | 1025/10000 [00:04<00:38, 231.98it/s]
# Epoch 2
# Batch 1000
# Loss is: 1.5703411674499512
# Accuracy is:  0.892
#  20%|███████▌                             | 2038/10000 [00:08<00:33, 239.74it/s]
# Epoch 2
# Batch 2000
# Loss is: 1.5466253172159194
# Accuracy is:  0.915
#  30%|███████████▏                         | 3019/10000 [00:14<01:08, 101.22it/s]
# Epoch 2
# Batch 3000
# Loss is: 1.5553260558843613
# Accuracy is:  0.906
#  40%|██████████████▉                      | 4028/10000 [00:20<00:28, 209.46it/s]
# Epoch 2
# Batch 4000
# Loss is: 1.533757053732872
# Accuracy is:  0.927
#  50%|██████████████████▋                  | 5042/10000 [00:27<00:22, 221.28it/s]
# Epoch 2
# Batch 5000
# Loss is: 1.5496256562471389
# Accuracy is:  0.91
#  60%|██████████████████████▎              | 6027/10000 [00:33<00:27, 146.46it/s]
# Epoch 2
# Batch 6000
# Loss is: 1.5430064175128937
# Accuracy is:  0.918
#  70%|█████████████████████████▉           | 7019/10000 [00:39<00:16, 181.73it/s]
# Epoch 2
# Batch 7000
# Loss is: 1.5352908782958985
# Accuracy is:  0.923
#  80%|█████████████████████████████▋       | 8028/10000 [00:44<00:08, 223.50it/s]
# Epoch 2
# Batch 8000
# Loss is: 1.5319221433401107
# Accuracy is:  0.928
#  90%|█████████████████████████████████▍   | 9034/10000 [00:48<00:04, 214.99it/s]
# Epoch 2
# Batch 9000
# Loss is: 1.5410418276786804
# Accuracy is:  0.919
# 100%|████████████████████████████████████| 10000/10000 [00:53<00:00, 187.81it/s]
# Epoch 2
# Batch 10000
# Loss is: 1.5308854658603668
# Accuracy is:  0.931

# %% [markdown]
# ⬆️ This requires a bit of additional work

# %%
all_preds = []
for i in range(X_test.shape[0]):
    X = torch.tensor(X_test[i].reshape((-1, 28, 28))).float()
    y = torch.tensor(y_train[samp]).long()
    
    pred = model_conv(X)
    all_preds.append(torch.argmax(pred, dim=1))

# %%
all_preds = np.array([int(x) for x in all_preds])

# %%
accuracy_score(y_test, all_preds)
# Out:
# 0.9295

# %% [markdown]
# Hmmmm, Convolutional Bobby, you did a bit worse(
#
# Though, never stop grinding and you'll get it and beat your linear brother
